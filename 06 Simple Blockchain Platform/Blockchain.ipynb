# %%
import datetime
import hashlib

class Block:
    blockNo = 0
    data = None
    next = None
    hash = None
    nonce = 0
    previous_hash = 0x0
    timestamp = datetime.datetime.now()

    def __init__(self, data):
        self.data = data

    def hash(self):
        h = hashlib.sha256()
        h.update(
        str(self.nonce).encode('utf-8') +
        str(self.data).encode('utf-8') +
        str(self.previous_hash).encode('utf-8') +
        str(self.timestamp).encode('utf-8') +
        str(self.blockNo).encode('utf-8')
        )
        return h.hexdigest()

    def __str__(self):
        return "Block Hash: " + str(self.hash()) + "\nBlockNo: " + str(self.blockNo) + "\nBlock Data: " + str(self.data) + "\nHashes: " + str(self.nonce) + "\n--------------"

class Blockchain:

    diff = 20
    maxNonce = 2**32
    target = 2 ** (256-diff)

    block = Block("Genesis")
    dummy = head = block

    def add(self, block):

        block.previous_hash = self.block.hash()
        block.blockNo = self.block.blockNo + 1

        self.block.next = block
        self.block = self.block.next

    def mine(self, block):
        for n in range(self.maxNonce):
            if int(block.hash(), 16) <= self.target:
                self.add(block)
                print(block)
                break
            else:
                block.nonce += 1

# %%
blockchain = Blockchain()

ENTER = 1
ADD = 2
QUIT = 3

def get_menu_choice():
                                 
    print()
    print('1. Enter a person\'s data')
    print('2. Add a new information')
    print('3. Quit the program')
    print()  
    
    try:
        choice = int(input('Enter your choice: '))
        
        while choice < ENTER or choice > QUIT :
            choice = int(input('Enter a valid choice: '))
            
        return choice
    
    except ValueError:
        print('The choice is not valid.') 
        
        
def enter_data ( title , change ) :
    
    b = []
    
    for i in range(len(title)) :
        a = input ('Please enter the ' + title[i] + ' :')
        change.append(a)
    
    return change
    
def add_data(title , change):
    
    a = input('What information do you want to add? ')
    title.append(a)
    
    b = input('Please enter the data of information :')
    change.append(b)
    
    return title , change

# %%
def main():
    
    choice = 0
    k = 0
    a = []
    data = {}
    title = [ 'gender' , 'age' , 'height' , 'weight' ]
    info = []
    change = []
        
    name = input (" Please enter a name : ")
    
    while choice != QUIT:
        
        choice = get_menu_choice()
        
        if choice == ENTER:
                      
            info.append ( enter_data ( title , change ) )
            
            for i in range(len(info)):
                blockchain.mine ( Block ( info[i] ) )
            
        elif choice == ADD:
            
            redata = add_data ( title , change )
            
            title = redata[0]
            
            info.append( redata[1] )
            
            for i in range(len(info)):
                
                blockchain.mine ( Block ( info[i] ) )
        
        print()
    
    while blockchain.head != None:
        print( blockchain.head )            
        blockchain.head = blockchain.head.next
        
main()
